# %%
# !pip install opencv-python-headless numpy pandas keras tensorflow
# !wget -O haarcascade_frontalface.xml https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# ...
# --2025-06-12 06:15:13--  https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml [following]
# --2025-06-12 06:15:13--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface.xml’
#
# ...

# %%
# ✅ Download Haar Cascade for face detection
# !wget -O haarcascade_frontalface.xml https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml

# ✅ Download pre-trained Age Detection Model (SSR-Net)
# !wget -O ssrnet_3_3_3_64.h5 https://github.com/yu4u/age-gender-estimation/releases/download/v0.5/ssrnet_3_3_3_64.h5

# ✅ Download pre-trained Emotion Detection Model (mini-XCEPTION)
# !wget -O emotion_model.hdf5 https://github.com/oarriaga/face_classification/releases/download/v0.1/fer2013_mini_XCEPTION.102-0.66.hdf5
# Out:
# --2025-06-12 06:15:14--  https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml [following]
# --2025-06-12 06:15:14--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface.xml’
#
# ...

# %%
# ✅ Step 2: Download and Load Pre-trained Models

# 1. Download Haar Cascade for Face Detection
# !wget -nc -O haarcascade_frontalface.xml https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml

# 2. Emotion Detection Model (mini-XCEPTION)
# !wget -nc -O emotion_model.hdf5 https://github.com/oarriaga/face_classification/releases/download/v0.1/fer2013_mini_XCEPTION.102-0.66.hdf5

# 3. Download Age Detection Model (SSRNet)
# !wget -nc https://github.com/yu4u/age-gender-estimation/releases/download/v0.5/ssrnet_3_3_3_64.h5

# 4. Load Models
import tensorflow as tf
from tensorflow.keras.models import load_model
import cv2

# Load face detector
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface.xml")

# Load age and emotion models
age_model = load_model('ssrnet_3_3_3_64.h5', compile=False)
emotion_model = load_model('emotion_model.hdf5', compile=False)

# Emotion classes
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
# Out:
# File ‘haarcascade_frontalface.xml’ already there; not retrieving.
# File ‘emotion_model.hdf5’ already there; not retrieving.
# File ‘ssrnet_3_3_3_64.h5’ already there; not retrieving.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-661223325> in <cell line: 0>()
#      19
#      20 # Load age and emotion models
# ---> 21 age_model = load_model('ssrnet_3_3_3_64.h5', compile=False)
#      22 emotion_model = load_model('emotion_model.hdf5', compile=False)
#      23
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath, custom_objects=custom_objects, compile=compile
#     198         )
#
# ...

# %%
import os
if os.path.exists("ssrnet_3_3_3_64.h5"):
    os.remove("ssrnet_3_3_3_64.h5")
    print("Deleted corrupted ssrnet_3_3_3_64.h5")
# Out:
# Deleted corrupted ssrnet_3_3_3_64.h5

# %%
# !wget -O ssrnet_3_3_3_64.h5 https://github.com/yu4u/age-gender-estimation/releases/download/v0.5/ssrnet_3_3_3_64.h5
# Out:
# --2025-06-12 06:29:37--  https://github.com/yu4u/age-gender-estimation/releases/download/v0.5/ssrnet_3_3_3_64.h5
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-06-12 06:29:38 ERROR 404: Not Found.
